# %% [markdown]
# # Step 1: Project Mining - Apache

# %%
import os 
import csv
import pandas as pd
import json
import pickle
root="/home/"
analysis_path=root+"previousResults/analyzedProjects/"
results_path="results/"
config_path=root+"configFiles/ApacheProjects"
projects_path=root+"projects"
import concurrent.futures

# %% [markdown]
# This notebook tries to recover the projects used in the previous experiment and, in the case of recovering them, checks that all the studied commits are still available.
#
# **NOTE:** Some projects not found in a first iteration have been searched in Software Heritage and included in the results shown below.

# %%
def check_git_project(project_name):

    print("Project: %s"%project_name)
        
    if os.path.exists("%s/%s.pickle"%(results_path, project_name)):
        print(" -> Project already checked")
        return
    
    folder  = "%s/%s/" % (projects_path, project_name)

    # CHECK IF PROJECT EXISTS
    if os.path.exists(folder):
        print(" -> Project exist in local folder!")
    else:
        print(" -> Project does not exist in local folder!")
        url="https://github.com/apache/%s"%project_name
        # !curl --head --fail $url > /dev/null 2>&1
        if _exit_code is not 0:
            print(" -> Project %s does not exist in GitHub!"%project_name)
            return
        else:

            # CLONE PROJECT
            git_url = "https://github.com/apache/%s.git" % project_name
            print(" -> Downloading project from GitHub ...")
            # !git clone $git_url $folder > /dev/null 2>&1
            print(" -> Project downloaded from GitHub")    

    # OPEN COMMITS FILE (PREVIOUS EXPERIMENT)
    commits = []
    with open(analysis_path+project_name+"/compilation.log.csv") as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            commits.append(row['COMMIT_ID'])

    # CHECK IF ALL COMMITS IN FILE EXIST IN GIT REPOSITORY
    commit_results = []
    n=1
    for sha in commits:
        print(" -> Commits checked : %d/%d"%(n, len(commits) ), end="\r")
        n+=1
        # !cd $folder && git log $sha > /dev/null 2>&1
        commit_results.append((sha, _exit_code))
    commits_df = pd.DataFrame(commit_results, columns=['Commit', "Status"])
    print("")

    # SAVE RESULTS (LOCAL)
    project = {
        'project': project_name,
        'commits': commits_df,
        'success': commits_df[commits_df['Status']==0]['Commit'].count(),
        'errors': commits_df[commits_df['Status']!=0]['Commit'].count()
    }

    # SAVE RESULTS (PICKLE FILE)
    with open("%s/%s.pickle"%(results_path,project_name), 'wb') as f:
        pickle.dump(project, f)

# %%
# Create results folder (if not exist)
if not os.path.exists(results_path):
    print("Create folder results/")
    os.mkdir(results_path)
else:
    print("results/ folder exists")
# Out:
# results/ folder exists

# %%
# Iterate projects from previous experiment
for project_name in [p for p in os.listdir(analysis_path) if os.path.isdir(analysis_path+p)]:
    check_git_project(project_name)
# Out:
# Project: roller
#  -> Project already checked
# Project: myfaces-portlet-bridge
#  -> Project exist in local folder!
#  -> Commits checked : 27/27
# Project: myfaces-html5
#  -> Project already checked
# Project: jena
#  -> Project already checked
# Project: maven-surefire
#  -> Project already checked
# Project: log4j-extras
#  -> Project already checked
# Project: servicemix4-bundles
#  -> Project already checked
# Project: qpid-proton
#  -> Project already checked
# Project: maven-enforcer
#  -> Project already checked
# Project: tuscany-sca-2.x
#  -> Project already checked
# Project: myfaces
#  -> Project already checked
# Project: webservices-commons-xmlschema
#  -> Project already checked
# Project: kalumet
#  -> Project already checked
# Project: mahout
#  -> Project already checked
# Project: oltu
#  -> Project already checked
# Project: uima-addons
#  -> Project already checked
# Project: maven-doxia
#  -> Project already checked
# Project: tika
#  -> Project already checked
# Project: oozie
#  -> Project already checked
# Project: streams
#  -> Project already checked
# Project: uima-ruta
#  -> Project already checked
# Project: maven-2
#  -> Project already checked
# Project: james-hupa
#  -> Project already checked
# Project: james-jsieve
#  -> Project already checked
# Project: james-protocols
#  -> Project already checked
# Project: webservices-axiom
#  -> Project exist in local folder!
#  -> Commits checked : 2790/2790
# Project: myfaces-extcdi
#  -> Project already checked
# Project: rampart
#  -> Project already checked
# Project: odftoolkit
#  -> Project already checked
# Project: vysper
#  -> Project exist in local folder!
#  -> Commits checked : 678/678
# Project: jackrabbit-oak
#  -> Project already checked
# Project: myfaces-extval
#  -> Project already checked
# Project: olingo-odata2
#  -> Project already checked
# Project: log4j-component
#  -> Project already checked
# Project: james-imap
#  -> Project already checked
# Project: qpid-jms
#  -> Project already checked
# Project: maven-plugins
#  -> Project already checked
# Project: james-jdkim
#  -> Project already checked
# Project: nuvem
#  -> Project already checked
# Project: whirr
#  -> Project already checked
# Project: maven-scm
#  -> Project already checked
# Project: tiles-autotag
#  -> Project already checked
# Project: olingo-odata4
#  -> Project already checked
# Project: maven-archetype
#  -> Project already checked
# Project: santuario-java
#  -> Project already checked
# Project: jclouds
#  -> Project already checked
# Project: webservices-xmlschema
#  -> Project does not exist in local folder!
#  -> Project webservices-xmlschema does not exist in GitHub!
# Project: uima-uimaj
#  -> Project already checked
# Project: velocity-tools
#  -> Project already checked
# Project: james-mime4j
#  -> Project already checked
# Project: maven-app-engine
#  -> Project already checked
# Project: struts-sandbox
#  -> Project already checked
# Project: maven
#  -> Project already checked
# Project: servicemix-components
#  -> Project already checked
# Project: sis
#  -> Project already checked
# Project: james-mailbox
#  -> Project already checked
# Project: servicemix
#  -> Project already checked
# Project: manifoldcf-integration-solr-4.x
#  -> Project already checked
# Project: velocity-engine
#  -> Project already checked
# Project: struts-examples
#  -> Project already checked
# Project: tuscany-sca-1.x
#  -> Project already checked
# Project: jackrabbit
#  -> Project already checked
# Project: servicemix4-kernel
#  -> Project already checked
# Project: uima-uimafit
#  -> Project already checked
# Project: uima-as
#  -> Project already checked
# Project: sirona
#  -> Project already checked
# Project: wink
#  -> Project already checked
# Project: tiles
#  -> Project already checked
# Project: jackrabbit-filevault
#  -> Project already checked
# Project: karaf-cave
#  -> Project already checked
# Project: pluto
#  -> Project already checked
# Project: myfaces-scripting
#  -> Project already checked
# Project: uima-ducc
#  -> Project already checked
# Project: maven-integration-testing
#  -> Project already checked
# Project: maven-doxia-tools
#  -> Project already checked
# Project: manifoldcf
#  -> Project already checked
# Project: servicemix3
#  -> Project already checked
# Project: servicemix4-specs
#  -> Project already checked
# Project: tajo
#  -> Project already checked
# Project: wicket
#  -> Project already checked
# Project: log4j-receivers
#  -> Project already checked
# Project: log4j-zeroconf
#  -> Project already checked
# Project: james-postage
#  -> Project already checked
# Project: webservices-neethi
#  -> Project exist in local folder!
#  -> Commits checked : 358/358
# Project: wookie
#  -> Project already checked
# Project: jackrabbit-ocm
#  -> Project already checked
# Project: maven-resources
#  -> Project already checked
# Project: servicemix4-features
#  -> Project already checked
# Project: isis
#  -> Project already checked
# Project: james-jspf
#  -> Project already checked
# Project: wss4j
#  -> Project exist in local folder!
#  -> Commits checked : 1943/1943
# Project: james-mailet
#  -> Project already checked
# Project: opennlp
#  -> Project already checked
# Project: shiro
#  -> Project already checked
# Project: openwebbeans
#  -> Project already checked
# Project: sandesha
#  -> Project already checked
# Project: maven-jxr
#  -> Project already checked
# Project: karaf-cellar
#  -> Project already checked
# Project: tomee
#  -> Project already checked
# Project: maven-plugin-testing
#  -> Project already checked

# %%
def getCommitInfo(project_name, commit_hash):
    folder  = "%s/%s/" % (projects_path, project_name)
    info=!cd $folder && git log $commit_hash --pretty=format:"%h|=|%ad|=|%s" --date=iso8601 | head -n 1
    return tuple(info[0].split("|=|"))

# %%
def createConfigFile(project):
    commits = []
    for elem in list(data['commits'].itertuples(index=False, name=False)):
        info = getCommitInfo(project['project'], elem[0][0:8])
        _, date, comment = info
        commits.append({
            "c_hash": elem[0][0:8],
            "date": date,
            "comment": comment
        })
    
    config={
        'project': project['project'],
        'git_url': "https://github.com/apache/%s.git" % project['project'],
        'last_commit': commits[-1]["c_hash"],
        'experiment': 1,
        'commits': commits
    }

    with open('%s/%s-config.json'%(config_path,project_name), 'w') as outfile:
        json.dump(config, outfile, indent=4)

# %%
if not os.path.exists(config_path):
    print("Create folder %s"%config_path)
    os.mkdir(config_path)

# %%
projects = []
for project_name in [p for p in os.listdir(analysis_path) if os.path.isdir(analysis_path+p)]:
    if os.path.exists(results_path+project_name+".pickle"):
        with open("results/%s.pickle"%project_name, 'rb') as f:
            data = pickle.load(f)
            percent_of_success = (data['success']/data['commits']['Commit'].count())*100
            projects.append((data['project'], data['success'], data['errors'],len(data['commits']), percent_of_success))
            if not os.path.exists('%s/%s-config.json'%(config_path,project_name)):
                if percent_of_success == 100:
                    print("Created config file of project %s"%project_name)
                    createConfigFile(data)
                else:
                    print("Project %s has not all the commits defined"%project_name)
            else:
                print("Config file of %s project already exist"%project_name)
# Out:
# Config file of roller project already exist
# Config file of myfaces-portlet-bridge project already exist
# Config file of myfaces-html5 project already exist
# Config file of jena project already exist
# Config file of maven-surefire project already exist
# Config file of log4j-extras project already exist
# Config file of servicemix4-bundles project already exist
# Config file of qpid-proton project already exist
# Config file of maven-enforcer project already exist
# Config file of tuscany-sca-2.x project already exist
# Project myfaces has not all the commits defined
# Config file of webservices-commons-xmlschema project already exist
# Config file of kalumet project already exist
# Config file of mahout project already exist
# Config file of oltu project already exist
# Config file of uima-addons project already exist
# Config file of maven-doxia project already exist
# Project tika has not all the commits defined
# Config file of oozie project already exist
# Project streams has not all the commits defined
# Config file of uima-ruta project already exist
# Config file of maven-2 project already exist
# Config file of james-hupa project already exist
# Config file of james-jsieve project already exist
# Project james-protocols has not all the commits defined
# Created config file of project webservices-axiom
# Project myfaces-extcdi has not all the commits defined
# Config file of rampart project already exist
# Config file of odftoolkit project already exist
# Config file of vysper project already exist
# Project jackrabbit-oak has not all the commits defined
# Config file of myfaces-extval project already exist
# Config file of olingo-odata2 project already exist
# Config file of log4j-component project already exist
# Project james-imap has not all the commits defined
# Config file of qpid-jms project already exist
# Config file of maven-plugins project already exist
# Config file of james-jdkim project already exist
# Config file of nuvem project already exist
# Config file of whirr project already exist
# Config file of maven-scm project already exist
# Config file of tiles-autotag project already exist
# Config file of olingo-odata4 project already exist
# Project maven-archetype has not all the commits defined
# Project santuario-java has not all the commits defined
# Config file of jclouds project already exist
# Config file of uima-uimaj project already exist
# Config file of velocity-tools project already exist
# Config file of james-mime4j project already exist
# Config file of maven-app-engine project already exist
# Config file of struts-sandbox project already exist
# Config file of maven project already exist
# Config file of servicemix-components project already exist
# Project sis has not all the commits defined
# Project james-mailbox has not all the commits defined
# Config file of servicemix project already exist
# Config file of manifoldcf-integration-solr-4.x project already exist
# Config file of velocity-engine project already exist
# Config file of struts-examples project already exist
# Config file of tuscany-sca-1.x project already exist
# Project jackrabbit has not all the commits defined
# Config file of servicemix4-kernel project already exist
# Config file of uima-uimafit project already exist
# Config file of uima-as project already exist
# Config file of sirona project already exist
# Config file of wink project already exist
# Config file of tiles project already exist
# Project jackrabbit-filevault has not all the commits defined
# Config file of karaf-cave project already exist
# Config file of pluto project already exist
# Config file of myfaces-scripting project already exist
# Project uima-ducc has not all the commits defined
# Config file of maven-integration-testing project already exist
# Config file of maven-doxia-tools project already exist
# Project manifoldcf has not all the commits defined
# Config file of servicemix3 project already exist
# Config file of servicemix4-specs project already exist
# Config file of tajo project already exist
# Config file of wicket project already exist
# Config file of log4j-receivers project already exist
# Config file of log4j-zeroconf project already exist
# Config file of james-postage project already exist
# Config file of webservices-neethi project already exist
# Config file of wookie project already exist
# Project jackrabbit-ocm has not all the commits defined
# Config file of maven-resources project already exist
# Config file of servicemix4-features project already exist
# Config file of isis project already exist
# Config file of james-jspf project already exist
# Config file of wss4j project already exist
# Project james-mailet has not all the commits defined
# Project opennlp has not all the commits defined
# Project shiro has not all the commits defined
# Config file of openwebbeans project already exist
# Config file of sandesha project already exist
# Config file of maven-jxr project already exist
# Config file of karaf-cellar project already exist
# Config file of tomee project already exist
# Config file of maven-plugin-testing project already exist

# %%
# View a quick resume of this step
df = pd.DataFrame(projects, columns = ['Project', 'Success', 'Fail', 'Total', '% SUCCESS'])
df.groupby("% SUCCESS").count()['Project']
df
# Out:
#                           Project  Success  Fail  Total   % SUCCESS
# 0                          roller     3130     0   3130  100.000000
# 1          myfaces-portlet-bridge       27     0     27  100.000000
# 2                   myfaces-html5       77     0     77  100.000000
# 3                            jena     2680     0   2680  100.000000
# 4                  maven-surefire     1677     0   1677  100.000000
# 5                    log4j-extras      213     0    213  100.000000
# 6             servicemix4-bundles     7228     0   7228  100.000000
# 7                     qpid-proton     1364     0   1364  100.000000
# 8                  maven-enforcer      411     0    411  100.000000
# 9                 tuscany-sca-2.x     4310     0   4310  100.000000
# 10                        myfaces        0  2367   2368    0.000000
# 11  webservices-commons-xmlschema      373     0    373  100.000000
# 12                        kalumet      172     0    172  100.000000
# 13                         mahout     3156     0   3156  100.000000
# 14                           oltu      741     0    741  100.000000
# 15                    uima-addons      102     0    102  100.000000
# 16                    maven-doxia     1543     0   1543  100.000000
# 17                           tika      386  1866   2252   17.140320
# 18                          oozie     1423     0   1423  100.000000
# 19                        streams        0    69     69    0.000000
# 20                      uima-ruta     1018    87   1105   92.126697
# 21                        maven-2     5636     0   5636  100.000000
# 22                     james-hupa      686     0    686  100.000000
# 23                   james-jsieve      527     0    527  100.000000
# 24                james-protocols        0   591    591    0.000000
# 25              webservices-axiom     2790     0   2790  100.000000
# 26                 myfaces-extcdi      167     1    168   99.404762
# 27                        rampart      878     0    878  100.000000
# 28                     odftoolkit      726     0    726  100.000000
# 29                         vysper      678     0    678  100.000000
# ..                            ...      ...   ...    ...         ...
# 69                          pluto     1488     0   1488  100.000000
# 70              myfaces-scripting      843     0    843  100.000000
# 71                      uima-ducc     1783   644   2427   73.465183
# 72      maven-integration-testing     2042     0   2042  100.000000
# 73              maven-doxia-tools      306     0    306  100.000000
# 74                     manifoldcf     1938   480   2418   80.148883
# 75                    servicemix3     2968     0   2968  100.000000
# 76              servicemix4-specs      254     0    254  100.000000
# 77                           tajo     1212     0   1212  100.000000
# 78                         wicket    14818     0  14818  100.000000
# 79                log4j-receivers       96     0     96  100.000000
# 80                 log4j-zeroconf       25     0     25  100.000000
# 81                  james-postage       74     0     74  100.000000
# 82             webservices-neethi      358     0    358  100.000000
# 83                         wookie     1921     0   1921  100.000000
# 84                 jackrabbit-ocm       37   358    395    9.367089
# 85                maven-resources      149     0    149  100.000000
# 86           servicemix4-features     1085     0   1085  100.000000
# 87                           isis     4817     0   4817  100.000000
# 88                     james-jspf      621     0    621  100.000000
# 89                          wss4j     1943     0   1943  100.000000
# 90                   james-mailet        0    66     66    0.000000
# 91                        opennlp       19  1209   1228    1.547231
# 92                          shiro        1   687    688    0.145349
# 93                   openwebbeans     3088     0   3088  100.000000
# 94                       sandesha      884     0    884  100.000000
# 95                      maven-jxr      232     0    232  100.000000
# 96                   karaf-cellar      460     0    460  100.000000
# 97                          tomee     8916     0   8916  100.000000
# 98           maven-plugin-testing       98     0     98  100.000000
#
# [99 rows x 5 columns]
