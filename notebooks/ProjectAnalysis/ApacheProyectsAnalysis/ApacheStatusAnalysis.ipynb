# %% [markdown]
# # Step 3.1: Apache Status Analysis

# %%
import pandas as pd 
import os

# %%
# Open Results
df = pd.read_csv('ApacheStatusCheckerResults.csv')

# %% [markdown]
# In the following table we can see, for each project:
# - Original: commits where they detected a building system (Maven) and built successfully (Previous Experiment)
# - Replicated: commits where they detected a system build (Maven) and we have built successfully (Current experiment)
# - Real Replicated: commits where we have detected a build system (Maven) and have been able to build successfully (Current experiment).
# - Our Replicated + Fixes: of commits where we have detected any system build (Ant/Maven) and were able to build successfully.
# - Complete: # of commits we have been able to build successfully.
# - Original Buildable commits: # of commits in which they detected a pom.xml
# - Buildable commits: # of commits in which we detected a pom.xml
# - TotalCommits: # of repository commits.

# %%
df
# Out:
#                             Project  TotalCommits  Original Buildable commits  \
# 0                              isis          4817                        2062
# 1                        james-hupa           686                         677
# 2                       james-jdkim           124                         123
# 3                      james-jsieve           527                         473
# 4                        james-jspf           621                         446
# 5                      james-mime4j           733                         722
# 6                     james-postage            74                          63
# 7                           jclouds          5074                        1039
# 8                              jena          2680                        2647
# 9                           kalumet           172                         170
# 10                       karaf-cave           103                         103
# 11                     karaf-cellar           460                         460
# 12                  log4j-component            68                          68
# 13                     log4j-extras           213                         213
# 14                  log4j-receivers            96                          96
# 15                   log4j-zeroconf            25                          25
# 16                           mahout          3156                        3117
# 17  manifoldcf-integration-solr-4.x          3355                           3
# 18                            maven          9427                        9196
# 19                          maven-2          5636                        5405
# 20                 maven-app-engine            54                          54
# 21                      maven-doxia          1543                        1541
# 22                maven-doxia-tools           306                         303
# 23                   maven-enforcer           411                         408
# 24        maven-integration-testing          2042                        2037
# 25                        maven-jxr           232                         227
# 26                    maven-plugins         11812                       11221
# 27             maven-plugin-testing            98                          96
# 28                  maven-resources           149                         147
# 29                        maven-scm          1789                        1769
# ..                              ...           ...                         ...
# 49                      servicemix3          2968                        2968
# 50              servicemix4-bundles          7228                        7227
# 51             servicemix4-features          1085                        1084
# 52               servicemix4-kernel           526                         525
# 53                servicemix4-specs           254                         254
# 54            servicemix-components           225                         225
# 55                           sirona           718                         718
# 56                  struts-examples            68                          67
# 57                   struts-sandbox          1875                         353
# 58                             tajo          1212                        1212
# 59                            tiles          1066                        1023
# 60                    tiles-autotag           110                         107
# 61                            tomee          8916                        6955
# 62                  tuscany-sca-1.x           515                         514
# 63                  tuscany-sca-2.x          4310                        4309
# 64                      uima-addons           102                          98
# 65                          uima-as          1409                         389
# 66                        uima-ruta          1105                         860
# 67                     uima-uimafit           236                         235
# 68                       uima-uimaj          3863                         867
# 69                  velocity-engine          3753                         570
# 70                   velocity-tools          1207                         460
# 71                           vysper           678                         671
# 72    webservices-commons-xmlschema           373                         336
# 73               webservices-neethi           358                         213
# 74                            whirr           568                         564
# 75                           wicket         14818                        7508
# 76                             wink           892                         891
# 77                           wookie          1921                         151
# 78                            wss4j          1943                        1364
#
#     Original  Original (%)  Replicated  Replicated (%)  \
# 0        300     14.548982          90        4.364694
# 1         96     14.180207           0        0.000000
# 2          9      7.317073           9        7.317073
# 3        140     29.598309           0        0.000000
# 4        166     37.219731         166       37.219731
# 5        108     14.958449          70        9.695291
# 6          0      0.000000           0        0.000000
# 7          0      0.000000           0        0.000000
# 8        376     14.204760         329       12.429165
# 9         63     37.058824           5        2.941176
# 10        82     79.611650          31       30.097087
# 11        25      5.434783           1        0.217391
# 12        46     67.647059          46       67.647059
# 13       197     92.488263         197       92.488263
# 14         0      0.000000           0        0.000000
# 15        11     44.000000          11       44.000000
# 16       726     23.291627         577       18.511389
# 17         3    100.000000           3      100.000000
# 18      1694     18.421053        1704       18.529796
# 19      1150     21.276596        1120       20.721554
# 20        38     70.370370          38       70.370370
# 21       184     11.940299         155       10.058404
# 22       119     39.273927         119       39.273927
# 23       177     43.382353         122       29.901961
# 24       380     18.654885         380       18.654885
# 25       209     92.070485         225       99.118943
# 26        21      0.187149          21        0.187149
# 27        90     93.750000          90       93.750000
# 28        90     61.224490          90       61.224490
# 29      1293     73.092142        1292       73.035613
# ..       ...           ...         ...             ...
# 49         0      0.000000           0        0.000000
# 50      3961     54.808358        1707       23.619759
# 51         1      0.092251           0        0.000000
# 52         0      0.000000           0        0.000000
# 53       159     62.598425           0        0.000000
# 54        55     24.444444           0        0.000000
# 55       659     91.782730         661       92.061281
# 56        65     97.014925          65       97.014925
# 57       175     49.575071         175       49.575071
# 58         0      0.000000           0        0.000000
# 59       639     62.463343         482       47.116325
# 60        57     53.271028          18       16.822430
# 61         0      0.000000           0        0.000000
# 62         0      0.000000           0        0.000000
# 63         0      0.000000           0        0.000000
# 64        25     25.510204           0        0.000000
# 65         0      0.000000           0        0.000000
# 66         0      0.000000           0        0.000000
# 67       171     72.765957           4        1.702128
# 68         0      0.000000           0        0.000000
# 69       525     92.105263         525       92.105263
# 70       296     64.347826         296       64.347826
# 71       555     82.712370           1        0.149031
# 72       318     94.642857         320       95.238095
# 73        61     28.638498          55       25.821596
# 74        74     13.120567           0        0.000000
# 75      1407     18.740011         656        8.737347
# 76         0      0.000000           0        0.000000
# 77         0      0.000000           0        0.000000
# 78       460     33.724340         317       23.240469
#
#     Real Buildable commits  Real Replicated  Real Replicated (%)  Ant Fails  \
# 0                     2062               90             4.364694          0
# 1                      677                0             0.000000          0
# 2                      123                9             7.317073          0
# 3                      473                0             0.000000         51
# 4                      446              166            43.229167          0
# 5                      722               70             9.695291          0
# 6                       63                0             0.000000          8
# 7                     5072               94             1.853312          0
# 8                     2647              329            12.429165          0
# 9                      170                5             2.941176          0
# 10                     103               31            30.097087          0
# 11                     460                1             0.217391          0
# 12                      68               46            76.666667          0
# 13                     213              197            92.488263          0
# 14                      96                0             0.000000          0
# 15                      25               11            44.000000          0
# 16                    3117              577            18.511389          4
# 17                       3                3           100.000000       1582
# 18                    9196             1704            18.529796          0
# 19                    5405             1120            20.721554          0
# 20                      54               38            70.370370          0
# 21                    1541              155            10.058404          0
# 22                     303              119            39.273927          0
# 23                     408              122            29.901961          0
# 24                    2037              380            18.654885          0
# 25                     227              225            99.118943          0
# 26                   11810              369             3.124471          0
# 27                      96               90            93.750000          0
# 28                     147               90            61.224490          0
# 29                    1769             1292            73.035613          0
# ..                     ...              ...                  ...        ...
# 49                    2968                0             0.000000          0
# 50                    7227             1707            23.619759          0
# 51                    1084                0             0.000000          0
# 52                     525                0             0.000000          0
# 53                     254                0             0.000000          0
# 54                     225                0             0.000000          0
# 55                     718              661            92.061281          0
# 56                      67               65            97.014925          0
# 57                     353              175            49.575071          0
# 58                    1212                0             0.000000          0
# 59                    1023              482            47.116325         34
# 60                     107               18            16.822430          0
# 61                    8916                0             0.000000          0
# 62                     514                0             0.000000          0
# 63                    4309                0             0.000000          0
# 64                      98                0             0.000000          0
# 65                     389                0             0.000000          0
# 66                     860                0             0.000000          0
# 67                     235                4             1.702128          0
# 68                     867                0             0.000000          0
# 69                     570              525            92.105263          0
# 70                     460              296            64.347826        645
# 71                     671                1             0.149031          4
# 72                     336              320            95.238095         12
# 73                     213               55            25.821596          9
# 74                     564                0             0.000000          0
# 75                    7508              656             8.737347          0
# 76                     891                0             0.000000          0
# 77                     151                0             0.000000       1396
# 78                    1364              317            29.351852        306
#
#     Ant Success  Real Buildable commits + Ant  Real Replicated + Ant  \
# 0             0                          2062                     90
# 1             0                           677                      0
# 2             0                           123                      9
# 3            81                           525                     81
# 4            62                           446                    228
# 5             0                           722                     70
# 6             0                            71                      0
# 7             0                          5072                     94
# 8             0                          2647                    329
# 9             0                           170                      5
# 10            0                           103                     31
# 11            0                           460                      1
# 12            8                            68                     54
# 13            0                           213                    197
# 14            0                            96                      0
# 15            0                            25                     11
# 16           31                          3152                    608
# 17         1766                          3351                   1769
# 18            0                          9196                   1704
# 19            0                          5405                   1120
# 20            0                            54                     38
# 21            0                          1541                    155
# 22            0                           303                    119
# 23            0                           408                    122
# 24            0                          2037                    380
# 25            0                           227                    225
# 26            0                         11810                    369
# 27            0                            96                     90
# 28            0                           147                     90
# 29            0                          1769                   1292
# ..          ...                           ...                    ...
# 49            0                          2968                      0
# 50            0                          7227                   1707
# 51            0                          1084                      0
# 52            0                           525                      0
# 53            0                           254                      0
# 54            0                           225                      0
# 55            0                           718                    661
# 56            0                            67                     65
# 57            0                           353                    175
# 58            0                          1212                      0
# 59            0                          1057                    482
# 60            0                           107                     18
# 61            0                          8916                      0
# 62            0                           514                      0
# 63            0                          4309                      0
# 64            0                            98                      0
# 65            0                           389                      0
# 66            0                           860                      0
# 67            0                           235                      4
# 68            0                           867                      0
# 69            0                           570                    525
# 70           63                          1168                    359
# 71            0                           675                      1
# 72           25                           373                    345
# 73            2                           224                     57
# 74            0                           564                      0
# 75            0                          7508                    656
# 76            0                           891                      0
# 77            0                          1547                      0
# 78          548                          1934                    865
#
#     Real Replicated + Ant (%)   Complete
# 0                    4.364694   1.868383
# 1                    0.000000   0.000000
# 2                    7.317073   7.258065
# 3                   15.428571  15.370019
# 4                   51.121076  36.714976
# 5                    9.695291   9.549795
# 6                    0.000000   0.000000
# 7                    1.853312   1.852582
# 8                   12.429165  12.276119
# 9                    2.941176   2.906977
# 10                  30.097087  30.097087
# 11                   0.217391   0.217391
# 12                  79.411765  79.411765
# 13                  92.488263  92.488263
# 14                   0.000000   0.000000
# 15                  44.000000  44.000000
# 16                  19.289340  19.264892
# 17                  52.790212  52.727273
# 18                  18.529796  18.075740
# 19                  20.721554  19.872250
# 20                  70.370370  70.370370
# 21                  10.058404  10.045366
# 22                  39.273927  38.888889
# 23                  29.901961  29.683698
# 24                  18.654885  18.609207
# 25                  99.118943  96.982759
# 26                   3.124471   3.123942
# 27                  93.750000  91.836735
# 28                  61.224490  60.402685
# 29                  73.035613  72.219117
# ..                        ...        ...
# 49                   0.000000   0.000000
# 50                  23.619759  23.616491
# 51                   0.000000   0.000000
# 52                   0.000000   0.000000
# 53                   0.000000   0.000000
# 54                   0.000000   0.000000
# 55                  92.061281  92.061281
# 56                  97.014925  95.588235
# 57                  49.575071   9.333333
# 58                   0.000000   0.000000
# 59                  45.600757  45.215760
# 60                  16.822430  16.363636
# 61                   0.000000   0.000000
# 62                   0.000000   0.000000
# 63                   0.000000   0.000000
# 64                   0.000000   0.000000
# 65                   0.000000   0.000000
# 66                   0.000000   0.000000
# 67                   1.702128   1.694915
# 68                   0.000000   0.000000
# 69                  92.105263  13.988809
# 70                  30.736301  29.743165
# 71                   0.148148   0.147493
# 72                  92.493298  92.493298
# 73                  25.446429  15.921788
# 74                   0.000000   0.000000
# 75                   8.737347   4.427048
# 76                   0.000000   0.000000
# 77                   0.000000   0.000000
# 78                  44.725957  44.518785
#
# [79 rows x 16 columns]

# %%
df.mean()
# Out:
# TotalCommits                    1764.417722
# Original Buildable commits      1288.746835
# Original                         287.810127
# Original (%)                      37.197470
# Replicated                       185.620253
# Replicated (%)                    25.095413
# Real Buildable commits          1372.075949
# Real Replicated                  191.215190
# Real Replicated (%)               25.423654
# Ant Fails                         83.265823
# Ant Success                       32.734177
# Real Buildable commits + Ant    1482.582278
# Real Replicated + Ant            223.949367
# Real Replicated + Ant (%)         24.858411
# Complete                          22.382664
# dtype: float64

# %%
# Sum of each field
df.sum()
# Out:
# Project                         isisjames-hupajames-jdkimjames-jsievejames-jsp...
# TotalCommits                                                               139389
# Original Buildable commits                                                 101811
# Original                                                                    22737
# Original (%)                                                               2938.6
# Replicated                                                                  14664
# Replicated (%)                                                            1982.54
# Real Buildable commits                                                     108394
# Real Replicated                                                             15106
# Real Replicated (%)                                                       2008.47
# Ant Fails                                                                    6578
# Ant Success                                                                  2586
# Real Buildable commits + Ant                                               117124
# Real Replicated + Ant                                                       17692
# Real Replicated + Ant (%)                                                 1963.81
# Complete                                                                  1768.23
# dtype: object

# %%
df[['TotalCommits']].describe()
# Out:
#        TotalCommits
# count     79.000000
# mean    1764.417722
# std     2694.935048
# min       25.000000
# 25%      234.000000
# 50%      726.000000
# 75%     1898.000000
# max    14818.000000

# %%
ant_success = int(df['Ant Success'].sum())
ant_fails   = int(df['Ant Fails'].sum())
print("Ant success: %d"%ant_success)
print("Ant fails: %d"%ant_fails)
# Out:
# Ant success: 2586
# Ant fails: 6578

# %%
print("Buildable commits (Original) %d"%int(df['Original Buildable commits'].sum()))
print("Buildable commits (Our Study) %d"%int(df['Real Buildable commits'].sum()))
print("Buildable commits (Our Study + Ant) %d"%int(df['Real Buildable commits + Ant'].sum()))
# Out:
# Buildable commits (Original) 101811
# Buildable commits (Our Study) 108394
# Buildable commits (Our Study + Ant) 117124

# %% [markdown]
# Generate resume of Replication Experiment

# %%
report_df = df[['Project', 'TotalCommits','Original Buildable commits', 'Replicated']]
report_df.to_csv('replication_experiment_buildability_summary.csv', index=False)

# %% [markdown]
# In the next cell, we can see the projects where we detect commits that have building systems but they don't, getting different values in `Replicated` and `Real Replicated`

# %%
# Check projects with mistakes on original experiment
df[df['Replicated'] != df['Real Replicated']]
# Out:
#           Project  TotalCommits  Original Buildable commits  Original  \
# 7         jclouds          5074                        1039         0
# 26  maven-plugins         11812                       11221        21
#
#     Original (%)  Replicated  Replicated (%)  Real Buildable commits  \
# 7       0.000000           0        0.000000                    5072
# 26      0.187149          21        0.187149                   11810
#
#     Real Replicated  Real Replicated (%)  Ant Fails  Ant Success  \
# 7                94             1.853312          0            0
# 26              369             3.124471          0            0
#
#     Real Buildable commits + Ant  Real Replicated + Ant  \
# 7                           5072                     94
# 26                         11810                    369
#
#     Real Replicated + Ant (%)  Complete
# 7                    1.853312  1.852582
# 26                   3.124471  3.123942

# %%
# Projects in which we detect more buildable commits
diff_in_buildable_df = df[df['Original Buildable commits'] != df['Real Buildable commits']]
diff_in_buildable_df
# Out:
#           Project  TotalCommits  Original Buildable commits  Original  \
# 7         jclouds          5074                        1039         0
# 26  maven-plugins         11812                       11221        21
# 61          tomee          8916                        6955         0
#
#     Original (%)  Replicated  Replicated (%)  Real Buildable commits  \
# 7       0.000000           0        0.000000                    5072
# 26      0.187149          21        0.187149                   11810
# 61      0.000000           0        0.000000                    8916
#
#     Real Replicated  Real Replicated (%)  Ant Fails  Ant Success  \
# 7                94             1.853312          0            0
# 26              369             3.124471          0            0
# 61                0             0.000000          0            0
#
#     Real Buildable commits + Ant  Real Replicated + Ant  \
# 7                           5072                     94
# 26                         11810                    369
# 61                          8916                      0
#
#     Real Replicated + Ant (%)  Complete
# 7                    1.853312  1.852582
# 26                   3.124471  3.123942
# 61                   0.000000  0.000000

# %%
# Diff between our buildable commits and their buildable commits
their_buildable_commits = int(diff_in_buildable_df[['Original Buildable commits']].sum())
our_buildable_commits   = int(diff_in_buildable_df[['Real Buildable commits']].sum())
our_buildable_commits-their_buildable_commits
# Out:
# 6583

# %%
their_successfully_built_commits = int(diff_in_buildable_df[['Original']].sum())
our_successfully_built_commits   = int(diff_in_buildable_df[['Real Replicated']].sum())
our_successfully_built_commits-their_successfully_built_commits
# Out:
# 442

# %%
def buildabilityOverview(aux_df):
    buildable = aux_df['Original Buildable commits'].sum()
    original = aux_df['Original'].sum()
    replicated = aux_df['Replicated'].sum()
    print("Length: %s"%len(aux_df))
    print("Buildable commits (Original): %s"%buildable)
    print("Successfully built commits (Original): %s"%original)
    print("Fraction built (Original): %.2f"%(original*100/buildable))
    print("Fraction built (Replicated): %.2f"%(replicated*100/buildable))
    print("Successfully built commits (Replicated): %s"%replicated)
    
    print("Total commits: %s"%aux_df['TotalCommits'].sum())
    
    return aux_df[['Original (%)','Replicated (%)']].describe().transpose()

# %% [markdown]
# # All projects
# Below, we can see an overview of the buildability of all projects. The values are percentages.

# %%
# Total
buildabilityOverview(df)
# Out:
# Length: 79
# Buildable commits (Original): 101811
# Successfully built commits (Original): 22737
# Fraction built (Original): 22.33
# Fraction built (Replicated): 14.40
# Successfully built commits (Replicated): 14664
# Total commits: 139389
#                 count       mean        std  min       25%        50%  \
# Original (%)     79.0  37.197470  34.259306  0.0  2.908276  28.638498
# Replicated (%)   79.0  25.095413  33.076794  0.0  0.000000   8.737347
#
#                       75%    max
# Original (%)    65.997442  100.0
# Replicated (%)  41.636964  100.0

# %% [markdown]
# We calculate the values of quartiles Q1 and Q3

# %%
q1 = df['TotalCommits'].quantile(0.25)
q1
# Out:
# 234.0

# %%
q3 = df['TotalCommits'].quantile(0.75)
q3
# Out:
# 1898.0

# %% [markdown]
# # Short projects
# We get the buildability results for short projects (# of commits < Q1)

# %%
buildabilityOverview(df[ df['TotalCommits']< q1 ])
# Out:
# Length: 20
# Buildable commits (Original): 2311
# Successfully built commits (Original): 1129
# Fraction built (Original): 48.85
# Fraction built (Replicated): 37.91
# Successfully built commits (Replicated): 876
# Total commits: 2349
#                 count       mean        std  min        25%        50%  \
# Original (%)     20.0  49.846115  35.084146  0.0  23.671875  48.635514
# Replicated (%)   20.0  40.629057  39.971662  0.0   0.555556  31.495912
#
#                       75%        max
# Original (%)    82.726359  97.014925
# Replicated (%)  75.899844  99.118943

# %% [markdown]
# # Medium proyects
# We get the buildability results for medium projects (Q1 <= # of commits < Q3)

# %%
medium_df = df.query('TotalCommits >= %d and TotalCommits < %d'%(q1,q3))
buildabilityOverview(medium_df)
# Out:
# Length: 39
# Buildable commits (Original): 26903
# Successfully built commits (Original): 9602
# Fraction built (Original): 35.69
# Fraction built (Replicated): 22.48
# Successfully built commits (Replicated): 6049
# Total commits: 33103
#                 count       mean        std  min       25%        50%  \
# Original (%)     39.0  38.433182  34.035972  0.0  4.994934  36.242083
# Replicated (%)   39.0  20.992591  29.529009  0.0  0.000000   1.702128
#
#                       75%         max
# Original (%)    68.426267  100.000000
# Replicated (%)  38.246829   95.238095

# %% [markdown]
# # Large proyects
# We get the buildability results for large projects (# of commits >= Q3)

# %%
# Large proyects (>= Q1)
buildabilityOverview(df[ df['TotalCommits'] >= q3 ])
# Out:
# Length: 20
# Buildable commits (Original): 72597
# Successfully built commits (Original): 12006
# Fraction built (Original): 16.54
# Fraction built (Replicated): 10.66
# Successfully built commits (Replicated): 7739
# Total commits: 103937
#                 count       mean        std  min  25%        50%        75%  \
# Original (%)     20.0  22.139185  29.331318  0.0  0.0  16.485017  25.673890
# Replicated (%)   20.0  17.562272  28.311191  0.0  0.0   9.440663  19.171552
#
#                   max
# Original (%)    100.0
# Replicated (%)  100.0

# %% [markdown]
# # Wilcoxon test
# We used the Wilcoxon test to compare the buildability results obtained in the previous experiment with those obtained in the current experiment.

# %%
from scipy.stats import wilcoxon

original = list(df['Original (%)'])
replicated = list(df['Replicated (%)'])

wilcoxon(original,replicated)
# Out:
# WilcoxonResult(statistic=235.0, pvalue=5.560449422985147e-07)

# %% [markdown]
# We get a very low p-value, so we can say that both results are different.
